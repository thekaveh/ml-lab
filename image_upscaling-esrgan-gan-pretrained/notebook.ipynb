# %%
import urllib.request

from git import Repo

# %%
Repo.clone_from(url="https://github.com/xinntao/ESRGAN.git", to_path="./repos/ESRGAN")
# Out:
# <git.repo.base.Repo '/usr/src/app/image_upscaling-esrgan-gan-pretrained/repos/ESRGAN/.git'>

# %%
urllib.request.urlretrieve(url="https://drive.google.com/file/d/1TPrz5QKd8DHHt1k8SRtm6tMiPjz_Qene/view?usp=share_link", filename="./repos/ESRGAN/models/RRDB_ESRGAN_x4.pth")
# Out:
# ('./repos/ESRGAN/models/RRDB_ESRGAN_x4.pth',
#  <http.client.HTTPMessage at 0xffffa0403a00>)
